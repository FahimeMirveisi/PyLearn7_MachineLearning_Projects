# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
speed = [32, 111, 138, 28, 59, 77, 97]
stdd = np.std(speed)
varr= np.var(speed)

print(stdd)
print(varr)
# Out:
# 37.84501153334721
# 1432.2448979591834

# %%
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

per75 = np.percentile(ages, 75)
print(per75)

per90 = np.percentile(ages, 90)
print(per90)
# Out:
# 43.0
# 61.0

# %%
x = np.random.uniform(0.0, 5.0, 250)

plt.hist(x, 10)
plt.show()

#print(x)

# %%
x = np.random.uniform(0.0, 5.0, 100000)
plt.hist(x, 100)
plt.show()

# %%
x = np.random.normal(1.0, 20.0, 100000)
plt.hist(x, 100)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

lenx = len(x)
print("lenx:",lenx)
leny = len(y)
print("leny:", leny)

plt.scatter(x,y)
plt.show()
# Out:
# lenx: 13
# leny: 13

# %%
a1 = np.random.normal(5.0, 1.0, 1000)
a2 = np.random.normal(10.0, 2.0, 1000)

plt.scatter(a1, a2)
plt.show()

# %%
#x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
#y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print('r:', r)
print('p:', p)
print('std_err:', std_err)

def myfunc(x):
    return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# r: 0.01331814154297491
# p: 0.955558800440106
# std_err: 0.24627150586388075
